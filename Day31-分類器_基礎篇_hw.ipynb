# %%
# !python --version
# Out:
# Python 3.7.6

# %%
import pandas as pd
import numpy as np

from ckiptagger import WS, POS
from tqdm.notebook import tqdm

# %%
df_train = pd.read_csv('news_clustering_train.tsv', sep='\t')
df_test = pd.read_csv('news_clustering_test.tsv', sep='\t')

# %%
df_train
# Out:
#       index class                            title
# 0         0    體育         亞洲杯奪冠賠率：日本、伊朗領銜 中國竟與泰國並列
# 1         1    體育        9輪4球本土射手僅次武磊 黃紫昌要搶最強U23頭銜
# 2         2    體育             如果今年勇士奪冠，下賽季詹姆斯何去何從？
# 3         3    體育            超級替補！科斯塔本賽季替補出場貢獻7次助攻
# 4         4    體育          騎士6天里發生了啥？從首輪搶七到次輪3-0猛龍
# ...     ...   ...                              ...
# 1795   1795    遊戲  LOL：麻辣香鍋韓服Rank不合成打野刀？電刀巨魔新套路連勝中
# 1796   1796    遊戲            穩住，我們能贏！因為我們擁有這種強大的力量
# 1797   1797    遊戲          騰訊是怎樣毀掉《鬥戰神》這款可能成神的作品的？
# 1798   1798    遊戲                   LOL你不知道的黑科技打法！
# 1799   1799    遊戲                 遊戲拳皇各代的劇情都在講些什麼？
#
# [1800 rows x 3 columns]

# %%
train_titles = {row['index']: row['title'] for _, row in df_train.iterrows()}
train_classes = {row['index']: row['class'] for _, row in df_train.iterrows()}

test_titles = {row['index']: row['title'] for _, row in df_test.iterrows()}
test_classes = {row['index']: row['class'] for _, row in df_test.iterrows()}

# %%
all_news_class = ['體育', '財經', '科技', '旅遊', '農業', '遊戲']

# %% [markdown]
# # 斷詞 + POS

# %%
ws = WS('C:/Users/zero0/OneDrive/cupoy/NLP/Day007/data/')
pos = POS('C:/Users/zero0/OneDrive/cupoy/NLP/Day007/data/')

# %%
train_title_cuts = {}
for index, title in tqdm(train_titles.items()):
    # YOUR CODE HERE
    word_s = ws([title], sentence_segmentation=True)
    word_p = pos(word_s)
    # END YOUR CODE
    train_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1800.0), HTML(value='')))

# %%
test_title_cuts = {}
for index, title in tqdm(test_titles.items()):
    # YOUR CODE HERE
    word_s = ws([title], sentence_segmentation=True)
    word_p = pos(word_s)
    # END YOUR CODE
    test_title_cuts[index] = list(zip(word_s[0], word_p[0]))
# Out:
# HBox(children=(FloatProgress(value=0.0, max=600.0), HTML(value='')))

# %%
train_title_cuts[120]
# Out:
# [('國腳', 'Na'),
#  ('張呈棟', 'Nb'),
#  ('：', 'COLONCATEGORY'),
#  ('從', 'D'),
#  ('沒', 'D'),
#  ('想', 'VE'),
#  ('過', 'Di'),
#  ('自己', 'Nh'),
#  ('會', 'D'),
#  ('出', 'VC'),
#  ('一', 'Neu'),
#  ('本', 'Nf'),
#  ('書', 'Na')]

# %% [markdown]
# # Bag of Words (BOW)

# %%
word2index = {}
index2word = {}
# 產生字與index對應的關係
# YOUR CODE HERE
idx = 0
for word_pos_list in train_title_cuts.values():
    for word, _ in word_pos_list:
        if word not in word2index:
            word2index[word] = idx
            index2word[idx] = word
            idx += 1
# END YOUR CODE

# %%
word2index['溫暖']
# Out:
# 1512

# %%
index2word[1520]
# Out:
# '許'

# %%
def get_bow_vector(pairs, word2index):
    # YOUR CODE HERE
    vector = np.zeros(len(word2index))
    for word, _ in pairs:
        if word in word2index:
            vector[word2index[word]] += 1 
    # END YOUR CODE
    return vector

# %%
get_bow_vector(train_title_cuts[120], word2index)
# Out:
# array([0., 0., 1., ..., 0., 0., 0.])

# %% [markdown]
# # 排除較無意義的詞性

# %%
pos_analysis = {}
for _, pairs in train_title_cuts.items():
    for word, flag in pairs:
        if flag not in pos_analysis:
            pos_analysis[flag] = set()
        pos_analysis[flag].add(word)

for flag, words in pos_analysis.items():
    print(flag, ':', list(words)[:100])
    print('=======================')
# Out:
# Nb : ['帕克成', '李秋平', '卡納瓦羅', '皮爾洛', '·瞻', '魅族', '谷歌', '意大利杯', '德甲', '楊智復', '巔峰賽', '海富通', '東皇', '米切爾西蒙斯', '李白界', '國六', '皇馬', '殺里', '神帥', '特里', '博時', '星巴克', '海爾', '布茲德里克', '慧商', '斐濟', '庫里', '安永', '朱嘯虎', '紫鑫', '美宇', '烏迪內斯', '陳柯楓', '德帥', '德羅', '張大仙', '許', '張某', '堪比比薩', '哈登', '耀里', '騰訊王', '京新', '英特爾', '阿里雲', '嬴政', '拳皇', '亞亞·圖雷', '凱西', '克羅托內 ', '埃梅里', '周雲傑', '鍾馗', '胤祥', '羅永浩', '杜蘭特', '王昭君', '李白', '埃爾克森', '王者榮', '張呈棟', '纏中', '卓爾', '桑德羅', '維亞利', '韓寒', '德羅贊', '埃姆雷', '萬孚', '峽谷里', '舒斯特爾', '張藝謀', '何享健', '約翰塞納', '奧恰洛夫', '大豐', '詹姆斯', '尤文', '周評', '西蒙斯', '張掖篇', '拜仁', '安琪', '姆巴佩', '微博', '遼足', '2018世界杯', '新游', '余則成', '維特爾', '海王星', '杜蕾斯', '張本智和', '雷霆隊', '施之皓', '海因克斯 萊萬多夫斯基', '弗格森', '阿珂', '樊振東', '小智']
# =======================
# Na : ['大四', '報業', '力量', '帝', '素能', '新招', '盛贊', '戰績', '贏家', '爪子', '國腳', '心理', '特幣', '正負值', '龍頭', '柑橘', '鈣', '墒情', '紫薇', '國安', '排他性', '報告', '網友數', '海', '素顏', '挑戰', '樹莓', '茅台', '印度人', '理想', '籌股', '需求', '蛋', '兄弟', '樹木', '設計', '猴子', '仇', '魂牛', '路', '蜂農', '插秧期', '股票池', '生態', '龍蝦', '豬價', '規範', '兩護法', '淚', '博物', '稀罕物', '獸藥', '牛價', '決賽', '龍主', '身價', '好處', '困擾', '售價', '助力', '皇家', '飛豬', '總收入', '封號', '單位', '戰隊秀', '房價', '鱸', '上聯', '手續費', '生日歌', '脈衝式', '語言', '分戶', '忽悠團', '鐵路篇', '海產', '規劃', '橋段', '庭院', '小辣椒', '物品', '小牛', '關鍵', '淘寶客', '陷阱', '時間', '有效期', '獅', '水瓶', '載具', '老闆', '爆文', '策略', '搏擊', '飛車手', '狂漲粉', '水利', '美國人', '年齡']
# =======================
# COLONCATEGORY : ['：', ':']
# =======================
# Nc : ['貴州省', '國內', '深市', '宿城', '掌門', '雷區', '平邑', '希臘', '四國', '果嶺', '萊加內斯', '小丘鎮', '鄭州', '邊緣', '行協', '江夏鎮', '新化縣', '成中路', '官總', '自治縣', '臨洮', '梅縣', '山西', '廣交會', '鵬城', '縣城', '楚河', '南粵', '珠海市', '國安會', '大理', '岳陽市', '神壇', '盧氏縣', '孔子湖', '千島湖', '王者局', '大區', '滎經縣', '石鼓園', '長白山', '河岸', '斯里蘭卡', '風景道', '崇義', '萊茵河', '證監局', '曼城', '陝西', '北川', '燴面店', '巴釐島', '紅原月亮灣', '廣元', '馬略卡島', '九寨', '鮁魚圈區', '盱眙', '尼泊爾', '酒館', '唐山', '祁東縣', '蒼穹', '北海道', '寶閣', '潘帕斯', '公司', '休斯頓', '深圳', '滑縣', '馬德里', '五一', '德', '機場', '黑龍江', 'WKG&M-1世界', '孟津', '石家莊', '賽場', '天津', '維希', '宜賓', '球館', '火山口', '縣里', '央視', '家鄉', '華鎣', '工廠', '立夏苗山', '工行', '西安', '遼寧省', '溫州', '身邊', '西藏', '山海', '中棉', '華中區', '火焰山']
# =======================
# PAUSECATEGORY : ['、']
# =======================
# VB : ['再見', '護航', '加冕', '一網打盡', '導航', '鍍金', '分段', '應對', '充飢', '分組', '加起來', '抓來', '復仇', '退貨', '代打', '解圍', '鋪平', '扣分', '提前', '退改', '入賬', '退款', '效力', '計算出來', '分紅', '拍照', '解惑', '加持', '助威', '相比', '解密', '騙錢', '融資', '執教', '罵屌絲', '解體', '加油', '加工', '站台', '上架', '通話', '充氣', '領銜', '開戰', '定位', '罰款', '收回來']
# =======================
# WHITESPACE : [' ']
# =======================
# D : ['有沒有', '是否', '紛紛', '即將', '初', '或許', '互', '亂', '並', '突然', '終於', '從中', '別', '攜手', '不會', '需', '非', '相互', '很少', '率先', '簡直', '天南地北', '不能', '曾', '一', '時刻', '必須', '到底', '屢次', '真是', '常常', '本來', '屢', '迫不及待', '預先', '隨地', '將', '甚至', '真的', '親自', '大力', '無可', '獨', '即', '經常', '究竟', '終', '一直', '多', '會', '竟然', '大概', '盡快', '冒死', '那麼', '反野', '少', '絕對', '原來', '隨', '分別', '依然', '相', '變相', '親身', '立即', '還是', '要', '恐怕', '未必', '當下', '大幅', '屢屢', '至今', '不得', '沒', '怎麼', '怎能', '又', '還', '盡情', '凌空', '該', '居然', '剛剛', '應當', '到處', '哈哈', '應', '好在', '竟', '從來', '得', '能', '早', '先', '有', '應該', '依舊', '可能']
# =======================
# P : ['往', '至', '憑', '靠', '根據', '比如', '從', '按', '就', '慘遭', '關於', '比', '趁著', '遭', '於', '離', '如', '幫', '自從', '給', '為', '被', '在', '除', '到', '等', '除了', '因', '將', '和', '受', '距離', '針對', '趁', '為了', '對', '繼', '直至', '以', '待', '像', '自', '隨了', '隨', '臨', '把', '跟', '與', '當', '向', '用']
# =======================
# VG : ['應聘', '稱得上', '排', '稱', '美成', '屬於', '當上', '升任', '非', '叫做', '變成', '算', '算是', '任', '酷似', '叫', '作為', '堪稱', '排名', '類似', '並列', '改造成', '當成', '如', '充當', '形成', '評選', '稱作', '合成', '當', '理解為', '當作', '變', '疑似', '化', '成為', '名叫', '成', '稱為', '彷彿', '屈居', '賣成', '譽為', '做', '戰成', '集成', '封號', '居', '做成', '誤認成', '像', '猶如', '泛濫成', '投票成', '等於', '姓', '似', '排行', '建成', '為', '竟是']
# =======================
# Neu : ['60萬', '300萬', '91', '30', '1000', '一千', '32', '7000', '115', '47', '9-1', '一', '24.8億', '2萬', '715', '三百', '十六', '第九', '8', '500', '五', '1318', '24', '百萬', '98', '第9', '11億', '300', '64', '萬億', '400萬', '135', '一萬', '4000萬', '1', '七八千', '幾', '100', '2.5', '二〇三', '十萬', '二十', '八', '5.7', '1.8億', '(00926)', '三千億', '兩四', '1.1.2', '第114', '7', '37', '54', '三', '15', '600億', '20', '20億', '第四', '第33', '1699', '5.5', '5050', '3-0', '2', '2200', '2018千', '70萬', '500萬', '11', '（四）', '400', '2.37億', '48', '三十二', '四', '2000', '7億', '9-0', '（二）', '十五萬', '60多', '億', '200', '11.59億', '6', '百', '1299', '七', '711', '90', '3000億', '甲', '2000萬', '16', '10', '12', '一500', '第36', '05-06 ']
# =======================
# Nf : ['胎', '周', '支', '些', '輛', '票', '盤', '番', '筆', '頁', '掛', '級', '元', '晚', '名', '道', '篇', '度', '期', '台', '棵', '戶', '遍', '張', '款', '口', '路', '色', '歲', '頓', '門', '句', '頭', '英吋', '個', '種', '套', '畝', '槍', '步', '位', '分鐘', '斤', '場', '回', '方', '鍋', '招', '袋', '檔', '輪', '公里', '節', '群', '年', '座', '屆', '秒', '件', '噸', '批', '串', '美元', '片', '家', '股', '米', '部', '號', '關', '次', '天', '把', 'K', '層', '則', '班', '只', '刻', '塊', '分', '隻', '樣', '條', '類', '局', '處', '週', '隊', '日', '對', '項', '毛', '行', '株', '本', '碗', '所', '港元', '點']
# =======================
# VJ : ['吃上', '充', '遺傳', '來自', '新增', '出於', '適用', '脫', '發揮', '符合', '羨慕', '衝', '入選', '領先', '賽', '減', '爆發', '不到', '痛失', '喪失', '共享', '輸掉', '達到', '珍惜', '養有', '惜', '出', '贏得', '懼怕', '經歷', '歡迎', '出身', '分享', '歸屬於', '贏下', '緊缺', '失去', '抗', '仇', '歸', '沒', '沈迷', '煥發', '贊同', '不如', '展望', '限', '僅次於', '虧損', '耗', '超過', '得', '欣賞', '受', '含有', '缺少', '震撼到', '負於', '獲', '服', '近', '連接', '曝限', '替代', '逾', '曬', '嫌棄', '負', '過完', '發生', '翻倍', '透', '富', '年入', '冷落', '同情', '認', '順應', '晉級', '維持', '忽視', '偏愛', '自有', '享受', '獨佔', '大勝', '擁有', '納入', '適應', '值', '高達', '恪守', '看不過去', '忽略', '受到', '無', '認識', '毫無', '錯失', '入圍']
# =======================
# VD : ['發', '提供', '寄予', '拒賠', '還', '分', '贏', '欠', '收費', '予', '給', '郵給', '發放', '禁售', '發給', '借貸', '清繳', '傳', '付', '坑', '給予', '賣', '轉讓', '搶', '供應', '貸款', '速遞', '補繳', '送', '補貼', '白送', '輸給', '售', '輸', '貸', '交付', '借', '支付', '配']
# =======================
# Dfa : ['更', '最', '還要', '不大', '比較', '十分', '還', '更為', '頗', '越來越', '遠遠', '過於', '非常', '如此', '遠', '同樣', '有些', '這麼', '多', '較', '很', '過', '有點', '好', '極', '太', '超']
# =======================
# VH : ['掉', '平安好', '便宜', '漲停', '原始', '熱別', '好吃', '得寸進尺', '低', '連勝', '甜蜜', '巨大', '密', '主動', '爆表', '通車', '變幻莫測', '任性', '自主', '暴躁', '努力', '出名', '難得', '迷你', '頻繁', '理想', '不同', '交融', '系統', '久遠', '不當', '高速', '舊', '太少', '合格', '活躍', '徹底', '滯銷', '失落', '不對勁', '喜聞', '切實', '有情', '滑滑', '滿滿', '出線', '貴', '實惠', '低迷', '萎蔫', '驚世', '爆棚', '苦不堪言', '茫然', '出現', '值得', '驚人', '現', '有意思', '細', '疲軟', '紅', '怎麼辦', '淺', '復出', '近', '無緣', '不見了', '深入', '大減產', '負', '合適', '充足', '相應', '奇妙', '凝重', '主觀', '分布', '重要', '合作', '百出', '不行', '涼爽', '好意', '新', '自由', '腦溢血', '多樣', '莫名其妙', '辛勞', '繁多', '不善', '簡單', '鬼斧神工', '爭相鬥艷', '成長', '過時', '無效', '驚恐', '浪費']
# =======================
# Cbb : ['不僅', '而', '並', '但是', '致', '不如', '而是', '若', '不管', '否則', '並且', '假如', '就算', '因', '不然', '另外', '但', '可是', '只要', '連', '即使', '不過', '因為', '如果', '縱使', '既', '既然', '只是', '跟著', '要是', '只有', '還不如', '反而', '雖然']
# =======================
# Nd : ['8日', '周', '以前', '一大早', '長期', '今年', '00年', '半夜', '目前', '早晨', '夏日', '相親節', '6月', '現在', '米節', '5日', '寒武紀', '今日', '4月', '正月', '如今', '3月', '同時', '19年', '幾月份', '秋', '中旬', '旅遊節', '夏天', '夏季', '何時', '採摘節', '昔日', '最近', '當前', '今夏', '隆慶', '4日', '最後', '初夏', '2018年度', '永久', '後', '2005年', '90年', '2019年', '後來', '五月', '月季', '雍正', '不久', '首日', '昨天', '2020年', '未來', '晚間', '8月', '2018', '明日', '6日', '10點', '春', '九月', '31號', '夏', '短期', '12日', '五月份', '後期', '6旬', '下旬', '狗年', '臨時', '春天', '多久', '立夏', '花季', '近日', '23日', '三國', '當時', '春季', '旺季', '秋季', '熱天', '06日', '5號', '30號', '38+7', '當年', '荒古', '中期', '明年', '目後', '週一', '小時候', '以後', '大中', '1點', '2019']
# =======================
# VA : ['招商', '大笑', '報名', '養花', '健身', '跑', '頂風', '創業', '工作', '正名', '下滑', '結果', '保量', '牧育', '奪冠', '答復', '出單', '下降', '爭冠', '表態', '開課', '游水', '掛牌', '休閒', '育秧', '翻身', '求生', '摘帽', '出門', '相親', '戴罪', '見傾心', '吃飯', '日落', '爆錘', '出國', '溢出', '革命', '上班', '出高地', '違法', '收錢', '回家', '做生意', '變盤', '消費', '違規', '怒吼', '探界', '犯規', '加密', '謝幕', '花錢', '遠行', '點頭', '擒敵', '變通', '看過來', '成交', '除權', '還款', '下卡', '撒沙', '何去何從', '掙扎', '騎行', '逆襲', '爬山', '上雙', '打團', '領頭', '輪轉', '買單', '過閘', '跑跑', '抓頂', '睡', '炒房', '揮刀', '放飛', '下班', '申遺', '拍案叫絕', '下馬', '滑雪', '轉農', '行', '聚焦', '代言', '偷腥', '跳舞', '卡', '充值', '養家糊口', '立刷', '伸手', '投訴', '流動', '餵尿素', '紮營']
# =======================
# COMMACATEGORY : [',', '，']
# =======================
# Nes : ['近', '首', '頭', '另', '下', '同', '本', '前', '貴', '某', '何', '各', '後', '上', '每', '該']
# =======================
# QUESTIONCATEGORY : ['？']
# =======================
# VC : ['放棄', '踢', '更新', '指責', '耍', '帶上', '拍拍', '脫', '堵', '抵押', '開展', '存入', '開復', '精選', '栽種', '曝', '吃完', '迎來', '陪', '接觸', '舔', '封', '大修', '打開', '問倒', '面對', '搭上', '護', '重做', '調侃', '超爭', '清理', '咋回', '隱藏', '替補', '發起', '面試', '發行', '剪除', '移', '保留', '改', '踢出', '把握', '認養', '興起', '看看', '守護', '回應', '領導', '阻', '找回', '下調', '覽', '栽', '拿下', '炒作', '參考', '單騎', '反包', '看直', '扔', '接待', '毀滅', '到', '開好', '造就', '鋪開', '交', '解', '扶持', '辦理下來', '招', '尋找', '打擊', '單挑', '重建', '花用', '翻譯', '使用', '服務', '封禁', '興種', '覲見', '監控', '單殺', '推薦', '摔出', '繼承', '支持', '包里', '照看', '打服', '擺出', '膜拜', '規劃', '測', '還清', '喜迎', '虛擬']
# =======================
# EXCLAMATIONCATEGORY : ['！', '!']
# =======================
# Di : ['個', '過', '著', '起來', '了']
# =======================
# Nep : ['此', '其中', '哪', '這', '其', '什麼', '那', '啥']
# =======================
# Caa : ['暨', '及', '到', '至', '或', '和', '或是', 'VS', '比', '跟', '與', '又', '或者', '還是']
# =======================
# VCL : ['前來', '往', '走下', '進', '回歸', '赴', '走過', '升至', '退出', '走到', '路過', '進入', '上', '前往', '穿越', '栽進', '暗渡', '走進', '到達', '入', '走訪', '遊覽', '跌出', '住', '橫掃', '留在', '遠離', '玩遍', '出發到', '盤踞', '在', '存進', '登陸', '到', '重回', '重返', '跌至', '去', '出', '來到', '穿透', '穿過', '回', '回到', '過', '度過', '抵達', '深入', '直達', '蒞臨', '用於']
# =======================
# Neqa : ['滴滴', '更多', '哪些', '個個', '多少', '三分之一', '9.89%', '100%', '這些', '無數', '一點', '一切', '大量', '20%', '1/4', '任何', '0.8%', '15%', '其他', '這麼多', '1%', '有些', '90%', '步步', '10%', '四成', '8%', '句句', '半', '那些', '多', '很多', '6%', '百分之八十', '許多', '所有', '全', '41.8%', '其它', '一半', '大多', '67%', '不少', '30%', '大多數', '12%', '遍', '多點', '一些', '80%', '有的', '部分', '一處處']
# =======================
# Nh : ['自身', '個人', '自我', '別人', '俺們', '自己', '我', '私人', '對方', '父子倆', '各自', '它', '屌絲', '本人', '大家', '他', '人家', '雙方', '一方', '你', '她們', '誰', '她', '你們', '各位', '他們', '我們', '它們', '您', '小眾']
# =======================
# FW : ['CEO', 'ipad', 'BTC', 'DNF', 'P2P', 'Pro', ' 28', 'CBA', ' 利', 'ABCC', 'Uzi', 'Cotswolds', 'CDR', 'G3', 'AIC', '4H', 'VR ', 'U23', 'RPG', 'i7', 'Day', 'cosplay', 'Rank', 'max2', 'FOF', 'QM', 'UI', 'iPad', 'XQ', 'Xbox ', 'T', '6G+64', 'ios', 'ADC', 'TPP', 'RNG', 'EOS', 'A', 'eStarPro vs WF.D', '｜', 'X13', 'qq', 'W', 'MSCI', 'OMG', '│', 'OB', 'FPP', 'shou', 'TT', 'King James', 'Aloha', 'AD', 'Nvidia', 'Disneyland', 'e', '6 10.5', 'Minecraft', 'lol', 'DW', 'mAh+', 'Aurum ', '2', 'PPP', 'OV', 'Mc', 'AG', 'lck', 'mix2', 'KPL', 'eStar', 'FF ', 'LSPL', 'mc', 'CF', 'kpl', 'Brian Kelly', 'ST', 'Q', ' 秀', 'BAT', '4AM', 'CCR', 'SSR', 'iphone6plus', ' 樂', 'T+0', 'PS', 'AMD', 'iBoy', '+4', 'C', 'CCTV5', 'ban', 'Rookie', '5p', 'IOS', 'l ', 'MSI', 'QQ']
# =======================
# SHI : ['是', '像是']
# =======================
# VE : ['算', '確認', '盛贊', '呼', '估值', '說', '提猜', '看到', '炫耀', '問', '設想', '感嘆', '探索', '想起', '提醒', '判罰', '宣佈', '看出', '承諾', '想要', '允許', '賭', '申卡', '暗示', '揭曉', '公認', '考慮', '提', '提起', '預定', '預防', '證明', '要', '幻想', '見到', '發誓', '探討', '看看', '深思', '報道', '想好', '說明', '討說', '形容', '管', '預測', '慶祝', '披露', '想', '傳聞', '警惕', '訴說', '回答', '提到', '檢測', '介紹', '商量', '避免', '預計', '預告', '示範', '猜', '以為', '知詢', '發佈', '賭約', '預期', '研究', '樂見', '想到', '判斷', '講', '判定', '爆料', '見', '認為', '言', '談', '聽到', '查看', '回顧', '呼籲', '聊', '准', '鑒定', '講解', '精准', '限制', '稱', '證', '做到', '聯想', '防止', '廣播', '安排', '反對', '告訴', '公告', '調研', '查找']
# =======================
# DE : ['地', '的', '得', '之']
# =======================
# VHC : ['下來', '規模化', '擴張', '煩', '平衡', '減少', '愁壞', '開', '凍', '豐富', '麻煩', '結束', '肥', '愁死', '破', '團結', '增加', '國際化', '降低', '震驚', '公開', '溫暖', '熱', '穩定', '繁榮', '加快', '可憐', '現代化', '產生', '斷', '寶智能化', '滿足', '增長', '縮小', '機構化', '感動', '優化', '淡化', '增 ', '變動', '辛苦', '還原', '強化', '暫停', '恢復', '增強', '冷卻', '停', '傷', '陷', '普及', '告破', '壞']
# =======================
# Ng : ['中', '初', '之下', '之中', '上', '外', '以來', '之外', '內', '下', '左右', '前', '起', '之內', '以外', '間', '後', '為止', '裡', '之前', '底', '以下', '時', '之間', '之後', '來', '般', '之上', '以後', '以上']
# =======================
# VK : ['意味', '回憶', '想見', '需要', '需', '理解', '堅持', '期待', '恐', '介意', '流傳', '願', '感覺到', '希望', '忘', '意想不到', '信', '懷疑', '放心', '怕', '懂', '顯示', '面臨', '討厭', '遺憾', '意外', '依賴', '擔心', '抱歉', '忘記', '感謝', '欲', '覺得', '喜歡', '感受', '不滿', '指望', '害怕', '奇怪', '盼', '注意', '小心', '恨', '覺', '肯定', '有利於', '懂得', '同意', '不忘', '遇', '知道', '感覺', '確定', '願意', '瞭解', '曲解', '知', '所謂', '明白']
# =======================
# Ncd : ['中', '邊', '旁邊', '哪裡', '東西部', '東方', '上', '外', '東部', '底部', '旁', '上面', '這裡', '內', '下', '當中', '外面', '前沿', '畔', '間', '中間', '那裡', '西', '西部', '哪', '裡', '裡面', '中部', '末端', '方', '哪下', '對面', '那邊', '哪兒', '以下', '上方', '東', '一帶']
# =======================
# A : ['中', '新一代', '獨門', '上上', '雙', '母', '非', '獨角', '高度', '真正', '現行', '超級', '綜合', '新興', '眾', '寶有', '乒乓', '唯一', '共同', '麻辣', '二手', '地下', '優質', '必備', '大幅度', '彩色', '多餘', '野生', '前置', '基礎', '歐式', '常務', '長途', '後置', '中西', '最佳', '火紅', '小本', '額外', '同等', '基層', '碧藍', '單', '原', '獨家', '重磅', '現役', '一般', '主', '業餘', '總', '頭號', '國產', '超']
# =======================
# V_2 : ['有']
# =======================
# VL : ['使得', '故意', '愛', '便利', '趨於', '致', '開始', '習慣', '導致', '肯', '能', '持續', '使', '敢', '令', '愛好', '讓', '喜好', '後悔', '用來', '甘願', '不惜']
# =======================
# T : ['矣', '麼', '哪', '呢', '咯', '去', '啊', '嘛', '哦', '來', '嗎', '啦', '了', '吧', '的', '唄']
# =======================
# VI : ['取勝', '驚艷', '專用', '著稱']
# =======================
# DASHCATEGORY : ['—', '-']
# =======================
# I : ['瑪法里奧', '哦']
# =======================
# Dk : ['想不到', '那麼', '外傳', '據說', '那', '結果', '反過來', '據聞']
# =======================
# VF : ['申請', '鼓勵', '拒絕', '準備', '推選', '邀', '逼', '試試', '叫', '擬', '要求', '勸住', '試', '勸說', '圖', '判', '助', '止住', '繼續', '策劃', '停止', '率領', '催', '打算', '拒', '告誡', '帶領', '請']
# =======================
# Da : ['將近', '近', '正好', '光', '足足', '最多', '只', '不下', '幾近', '唯獨', '僅', '幾乎', '才', '共', '約']
# =======================
# PARENTHESISCATEGORY : ['」', '（', '）', '「', '》', '《', '(']
# =======================
# Nv : ['推薦', '解救', '回歸', '輔助', '護髮', '買單', '研究', '灌籃', '銷售', '配置', '私募', '創業', '問', '射擊', '工作', '錄制', '度假', '崩潰', '開發', '登山', '判罰', '管理', '訴訟', '增發', '批發', '航海', '思考', '抗戰', '分銷', '絕殺', '體驗', '旅遊', '疊加', '代理', '防治', '營銷', '安全', '組合', '生產', '經歷', '兼職', '翻譯', '關聯', '供電', '燃燒', '遊樂']
# =======================
# PERIODCATEGORY : ['·', '。']
# =======================
# VAC : ['移動', '蒸發', '集合', '推進', '上演', '動']
# =======================
# Dfb : ['些', '一點', '極了', '夠']
# =======================
# Cab : ['等等', '等']
# =======================
# SEMICOLONCATEGORY : ['；']
# =======================
# Neqb : ['以上', '多', '半']
# =======================
# ETCCATEGORY : ['…']
# =======================
# Cba : ['的話']
# =======================
# DOTCATEGORY : ['.']
# =======================

# %% [markdown]
# |         Type        |     Description    |
# |:-------------------:|:------------------:|
# | A                   | 非謂形容詞         |
# | Caa                 | 對等連接詞         |
# | Cab                 | 連接詞，如：等等   |
# | Cba                 | 連接詞，如：的話   |
# | Cbb                 | 關聯連接詞         |
# | D                   | 副詞               |
# | Da                  | 數量副詞           |
# | Dfa                 | 動詞前程度副詞     |
# | Dfb                 | 動詞後程度副詞     |
# | Di                  | 時態標記           |
# | Dk                  | 句副詞             |
# | DM                  | 定量式             |
# | I                   | 感嘆詞             |
# | Na                  | 普通名詞           |
# | Nb                  | 專有名詞           |
# | Nc                  | 地方詞             |
# | Ncd                 | 位置詞             |
# | Nd                  | 時間詞             |
# | Nep                 | 指代定詞           |
# | Neqa                | 數量定詞           |
# | Neqb                | 後置數量定詞       |
# | Nes                 | 特指定詞           |
# | Neu                 | 數詞定詞           |
# | Nf                  | 量詞               |
# | Ng                  | 後置詞             |
# | Nh                  | 代名詞             |
# | Nv                  | 名物化動詞         |
# | P                   | 介詞               |
# | T                   | 語助詞             |
# | VA                  | 動作不及物動詞     |
# | VAC                 | 動作使動動詞       |
# | VB                  | 動作類及物動詞     |
# | VC                  | 動作及物動詞       |
# | VCL                 | 動作接地方賓語動詞 |
# | VD                  | 雙賓動詞           |
# | VF                  | 動作謂賓動詞       |
# | VE                  | 動作句賓動詞       |
# | VG                  | 分類動詞           |
# | VH                  | 狀態不及物動詞     |
# | VHC                 | 狀態使動動詞       |
# | VI                  | 狀態類及物動詞     |
# | VJ                  | 狀態及物動詞       |
# | VK                  | 狀態句賓動詞       |
# | VL                  | 狀態謂賓動詞       |
# | V_2                 | 有                 |
# |                     |                    |
# | DE                  | 的之得地           |
# | SHI                 | 是                 |
# | FW                  | 外文               |
# |                     |                    |
# | COLONCATEGORY       | 冒號               |
# | COMMACATEGORY       | 逗號               |
# | DASHCATEGORY        | 破折號             |
# | DOTCATEGORY         | 點號               |
# | ETCCATEGORY         | 刪節號             |
# | EXCLAMATIONCATEGORY | 驚嘆號             |
# | PARENTHESISCATEGORY | 括號               |
# | PAUSECATEGORY       | 頓號               |
# | PERIODCATEGORY      | 句號               |
# | QUESTIONCATEGORY    | 問號               |
# | SEMICOLONCATEGORY   | 分號               |
# | SPCHANGECATEGORY    | 雙直線             |
# | WHITESPACE          | 空白               |

# %%
def get_bow_vector_with_selection(pairs, word2index):
    excluded_flags = [
        # 根據以上列舉出來的文字以及詞性表，請列出想要排除的詞性
        # YOUR CODE HERE
        'Caa', 'Cab','Cba', 'Cbb', 'Di', 'Dk', 'DM', 'I'
        # END YOUR CODE
    ]
    vector = np.zeros(len(word2index))
    for word, flag in pairs:
        if word in word2index and flag not in excluded_flags:
            vector[word2index[word]] += 1
    return vector

# %% [markdown]
# # Cosine Similarity

# %%
def cosine_similarity(bow1, bow2):
    # YOUR CODE HERE
    len_bow1 = (bow1 **2).sum() **(1/2)
    len_bow2 = (bow2 **2).sum() **(1/2)

    similarity = np.sum(bow1*bow2) /(len_bow1*len_bow2)
    # END YOUR CODE
    return similarity

# %%
bow1 = get_bow_vector(train_title_cuts[100], word2index)
bow2 = get_bow_vector(train_title_cuts[130], word2index)
cosine_similarity(bow1, bow2)
# Out:
# 0.08703882797784893

# %%
train_title_cuts[100]
# Out:
# [('山東', 'Nc'),
#  ('魯能', 'Nb'),
#  ('有沒有', 'D'),
#  ('可能', 'D'),
#  ('拿到', 'VC'),
#  ('今年', 'Nd'),
#  ('的', 'DE'),
#  ('中', 'A'),
#  ('超', 'A'),
#  ('冠軍', 'Na'),
#  ('？', 'QUESTIONCATEGORY')]

# %%
train_title_cuts[130]
# Out:
# [('NBA', 'Nb'),
#  ('和', 'Caa'),
#  ('CBA', 'FW'),
#  ('差距', 'Na'),
#  ('在', 'P'),
#  ('哪裡', 'Ncd'),
#  ('？', 'QUESTIONCATEGORY'),
#  ('6', 'Neu'),
#  ('張', 'Nf'),
#  ('圖', 'VF'),
#  ('一目瞭然', 'VH'),
#  ('！', 'EXCLAMATIONCATEGORY')]

# %% [markdown]
# # Group mean vector

# %%
group_vectors = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(train_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    news_class = train_classes[index]
    group_vectors[news_class].append(vector)

group_mean_vector = {}
for news_class, vectors in group_vectors.items():
    group_mean_vector[news_class] = np.mean(vectors, axis=0)
group_mean_vector
# Out:
# {'體育': array([0.04      , 0.00333333, 0.15666667, ..., 0.        , 0.        ,
#         0.        ]),
#  '財經': array([0.        , 0.        , 0.12333333, ..., 0.        , 0.        ,
#         0.        ]),
#  '科技': array([0.        , 0.        , 0.07666667, ..., 0.        , 0.        ,
#         0.        ]),
#  '旅遊': array([0.        , 0.        , 0.08666667, ..., 0.        , 0.        ,
#         0.        ]),
#  '農業': array([0.        , 0.        , 0.09333333, ..., 0.        , 0.        ,
#         0.        ]),
#  '遊戲': array([0.        , 0.        , 0.27      , ..., 0.00333333, 0.00333333,
#         0.00333333])}

# %% [markdown]
# # Group mean vector: 測試

# %%
classification = {news_class: [] for news_class in all_news_class}
for index, pairs in sorted(test_title_cuts.items()):
    vector = get_bow_vector_with_selection(pairs, word2index)
    if np.sum(np.square(vector)) == 0:
        continue

    max_val = -2.0
    max_class = None
    for news_class, ref_vector in group_mean_vector.items():
        val = cosine_similarity(ref_vector, vector)
        if val > max_val:
            max_class = news_class
            max_val = val

    classification[max_class].append(index)

# %%
from collections import Counter

for group, ids in classification.items():
    counter = Counter([test_classes[id] for id in ids])
    print('predict', group, ': ', counter)
# Out:
# predict 體育 :  Counter({'體育': 55, '財經': 16, '農業': 12, '旅遊': 11, '科技': 10, '遊戲': 8})
# predict 財經 :  Counter({'財經': 26, '體育': 6, '科技': 6, '農業': 5, '旅遊': 4, '遊戲': 3})
# predict 科技 :  Counter({'科技': 60, '旅遊': 29, '財經': 26, '農業': 23, '遊戲': 22, '體育': 18})
# predict 旅遊 :  Counter({'旅遊': 41, '財經': 13, '農業': 12, '遊戲': 10, '體育': 4, '科技': 4})
# predict 農業 :  Counter({'農業': 44, '科技': 14, '財經': 9, '旅遊': 9, '遊戲': 9, '體育': 8})
# predict 遊戲 :  Counter({'遊戲': 48, '財經': 10, '體育': 8, '旅遊': 6, '科技': 5, '農業': 4})
