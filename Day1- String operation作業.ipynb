# %% [markdown]
# # 作業目標：運用課程所學，操作字串達到預期輸出

# %% [markdown]
# ---

# %% [markdown]
# ## 讀入所需文件

# %%
import pandas as pd
#TSV文件有別於CSV的文件是使用\ t作為分隔符，CSV則是使用，作為分隔符。
dataset = pd.read_csv(r'Restaurant_Reviews.tsv', sep='\t')

# %%
all_review = dataset['Review'].values

# %% [markdown]
# ---

# %% [markdown]
# ### 計算有多少個句子是以 . 結尾

# %%
all_review[0].endswith(".") == True
# Out:
# True

# %%
n=0

for i in range(len(all_review)):
    if all_review[i].endswith('.') == True:
        n += 1

print('There are {} sentences end with .'.format(n))
# Out:
# There are 819 sentences end with .

# %% [markdown]
# ### 將所有. 換成 ,

# %%
for i in range(len(all_review)):
    all_review[i]=all_review[i].replace('.',',')

# %%
all_review
# Out:
#  and moist chicken on the inside,',
#        'The food was great as always, compliments to the chef,',
#        'Special thanks to Dylan T, for the recommendation on what to order :) All yummy for my tummy,',
#        'Awesome selection of beer,', 'Great food and awesome service!',
#        "One nice thing was that they added gratuity on the bill since our party was larger than 6 or 8, and they didn't expect more tip than that,",
#        'A FLY was in my apple juice,, A FLY!!!!!!!!',
#        'The Han Nan Chicken was also very tasty,',
#        'As for the service, I thought it was good,',
#        'The food was barely lukewarm, so it must have been sitting waiting for the server to bring it out to us,',
#        "Ryan's Bar is definitely one Edinburgh establishment I won't be revisiting,",
#        "Nicest Chinese restaurant I've been in a while,",
#        'Overall, I like there food and the service,',
# ...

# %% [markdown]
# ### 將所有sentence 中的第一個 the 置換成 The

# %%
for i in range(len(all_review)):
    all_review[i]= all_review[i].replace('the','The',1)

# %%
all_review
# Out:
#  and moist chicken on the inside,',
#        'The food was great as always, compliments to The chef,',
#        'Special thanks to Dylan T, for The recommendation on what to order :) All yummy for my tummy,',
#        'Awesome selection of beer,', 'Great food and awesome service!',
#        "One nice thing was that They added gratuity on the bill since our party was larger than 6 or 8, and they didn't expect more tip than that,",
#        'A FLY was in my apple juice,, A FLY!!!!!!!!',
#        'The Han Nan Chicken was also very tasty,',
#        'As for The service, I thought it was good,',
#        'The food was barely lukewarm, so it must have been sitting waiting for The server to bring it out to us,',
#        "Ryan's Bar is definitely one Edinburgh establishment I won't be revisiting,",
#        "Nicest Chinese restaurant I've been in a while,",
#        'Overall, I like There food and the service,',
# ...

# %% [markdown]
# ### 將偶數句子全部轉換為大寫，基數句子全部轉換為小寫

# %%
for i in range(len(all_review)):
    if i%2 == 0:
        all_review[i]=all_review[i].upper()
    else:
        all_review[i] = all_review[i].lower()

# %%
all_review
# Out:
#  and moist chicken on the inside,',
#        'THE FOOD WAS GREAT AS ALWAYS, COMPLIMENTS TO THE CHEF,',
#        'special thanks to dylan t, for the recommendation on what to order :) all yummy for my tummy,',
#        'AWESOME SELECTION OF BEER,', 'great food and awesome service!',
#        "ONE NICE THING WAS THAT THEY ADDED GRATUITY ON THE BILL SINCE OUR PARTY WAS LARGER THAN 6 OR 8, AND THEY DIDN'T EXPECT MORE TIP THAN THAT,",
#        'a fly was in my apple juice,, a fly!!!!!!!!',
#        'THE HAN NAN CHICKEN WAS ALSO VERY TASTY,',
#        'as for the service, i thought it was good,',
#        'THE FOOD WAS BARELY LUKEWARM, SO IT MUST HAVE BEEN SITTING WAITING FOR THE SERVER TO BRING IT OUT TO US,',
#        "ryan's bar is definitely one edinburgh establishment i won't be revisiting,",
#        "NICEST CHINESE RESTAURANT I'VE BEEN IN A WHILE,",
#        'overall, i like there food and the service,',
# ...

# %% [markdown]
# ### 將所有句子合併在一起，並以' / ' 為間隔

# %%
all_review_sum='/'.join(all_review)

# %%
all_review_sum
# Out:
# CE AND FOOD,/a fantastic neighborhood gem !!!/I CAN\'T WAIT TO GO BACK,/the plantains were the worst i\'ve ever tasted,/IT\'S A GREAT PLACE AND I HIGHLY RECOMMEND IT,/service was slow and not attentive,/I GAVE IT 5 STARS THEN, AND I\'M GIVING IT 5 STARS NOW,/your staff spends more time talking to themselves than me,/DESSERT: PANNA COTTA WAS AMAZING,/very good food, great atmosphere,1/DAMN GOOD STEAK,/total brunch fail,/PRICES ARE VERY REASONABLE, FLAVORS ARE SPOT ON, THE SAUCE IS HOME MADE, AND THE SLAW IS NOT DRENCHED IN MAYO,/the decor is nice, and the piano music soundtrack is pleasant,/THE STEAK WAS AMAZING,,,RGE FILLET RELLENO WAS THE BEST SEAFOOD PLATE I HAVE EVER HAD!/good food , good service ,/IT WAS ABSOLUTELY AMAZING,/i probably won\'t be back, to be honest,/WILL DEFINITELY BE BACK!/the sergeant pepper beef sandwich with auju sauce is an excellent sandwich as well,/HAWAIIAN BREEZE, MANGO MAGIC, AND PINEAPPLE DELIGHT ARE THE SMOOTHIES THAT I\'VE TRIED SO FAR AND THEY\'RE ALL
# ...
