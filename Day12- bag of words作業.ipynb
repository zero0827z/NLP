# %% [markdown]
# ## 作業目標：搭建一個bag of words模型

# %% [markdown]
# ---

# %%
import pandas as pd
import nltk
#nltk.download()
import numpy as np
dataset=pd.read_csv('Restaurant_Reviews.tsv',delimiter='\t',quoting=3)
corpus=dataset['Review'].values

# %% [markdown]
# ### 從文本中取出所有單字

# %%
whole_words = []
for sentence in corpus:
    tokenized_sentence = nltk.word_tokenize(sentence.lower())
    for word in tokenized_sentence:
        whole_words.append(word)

# %% [markdown]
# ### 移除重複單字

# %%
whole_words=set(whole_words)
print('共有{}個單字'.format(len(whole_words)))
# Out:
# 共有2085個單字

# %% [markdown]
# ### 建立字典使每一個單字有對應數值

# %%
word_index = {}
index_word = {}
n = 0
for word in whole_words:
    word_index[word]= n
    index_word[n]= word
    n += 1

# %%
word_index
# Out:
# {'easily': 0,
#  'think': 1,
#  'buldogis': 2,
#  'exceeding': 3,
#  'shall': 4,
#  'attached': 5,
#  'enough..': 6,
#  'tenders': 7,
#  'sure': 8,
#  'must-stop': 9,
#  'high': 10,
#  '10+': 11,
#  'covered': 12,
#  'noca': 13,
#  'greedy': 14,
#  'glass': 15,
#  'leather': 16,
#  'camelback': 17,
#  'apology': 18,
#  'non-customer': 19,
#  'combo': 20,
#  'hands-down': 21,
#  'book': 22,
#  'uninspired': 23,
#  'enjoyed': 24,
#  'away': 25,
#  'tv': 26,
#  'was': 27,
#  'spots': 28,
#  'instantly': 29,
#  'hella': 30,
#  'order': 31,
#  'station': 32,
#  'sandwiches': 33,
#  'dude': 34,
#  'bay': 35,
#  'stop': 36,
#  'connoisseur': 37,
#  'be': 38,
#  'operation': 39,
#  'spice': 40,
#  'ratio': 41,
#  'very': 42,
#  'noodles': 43,
#  'pale': 44,
#  'dos': 45,
#  'relax': 46,
#  'work': 47,
#  'spicier': 48,
#  'human': 49,
#  'charged': 50,
#  'satifying': 51,
#  'seasoned': 52,
#  'steakhouse': 53,
#  'strange': 54,
#  'veggitarian': 55,
#  'fireball': 56,
#  'containers': 57,
#  'drunk': 58,
#  'restaurant': 59,
#  'drastically': 60,
#  'each': 61,
#  "'re": 62,
#  'delightful': 63,
#  'disappointment': 64,
#  'when': 65,
#  'providing': 66,
#  'excuse': 67,
#  'missed': 68,
#  'also': 69,
#  'entire': 70,
#  'she': 71,
#  'vinegrette': 72,
#  'costco': 73,
#  '3': 74,
#  'meat': 75,
#  'simple': 76,
#  'mouth': 77,
#  'delicious': 78,
#  'its': 79,
#  'join': 80,
#  'fails': 81,
#  'full': 82,
#  'arrives': 83,
#  'duck': 84,
#  'what': 85,
#  'since': 86,
#  'bitches': 87,
#  'devine': 88,
#  'calligraphy': 89,
#  'yum': 90,
#  'dates': 91,
#  'leaves': 92,
#  'must': 93,
#  'dinner': 94,
#  'below': 95,
#  'tartar': 96,
#  'daily': 97,
#  'decided': 98,
#  'refreshing': 99,
#  'brick': 100,
#  "ya'all": 101,
#  'raving': 102,
#  'yama': 103,
#  'helped': 104,
#  'pork': 105,
#  'drawing': 106,
#  'room': 107,
#  'omelets': 108,
#  'deeply': 109,
#  'skimp': 110,
#  'mediterranean': 111,
#  'heard': 112,
#  'sunglasses': 113,
#  'disaster': 114,
#  'belly': 115,
#  'close': 116,
#  'breakfast': 117,
#  'impeccable': 118,
#  'continue': 119,
#  'fs': 120,
#  'cool': 121,
#  'sick': 122,
#  'batter': 123,
#  'buffets': 124,
#  'recently': 125,
#  'usual': 126,
#  'more': 127,
#  'disappointed': 128,
#  'handled': 129,
#  'other': 130,
#  'green': 131,
#  'unbelievably': 132,
#  'crema': 133,
#  'email': 134,
#  'long': 135,
#  'value': 136,
#  'boxes': 137,
#  'although': 138,
#  'customers': 139,
#  'wife': 140,
#  'crystals': 141,
#  'menu/': 142,
#  'bought': 143,
#  'weekly': 144,
#  '5': 145,
#  'rich': 146,
#  'wayyy': 147,
#  'blame': 148,
#  'rate': 149,
#  'ingredients': 150,
#  'food/service': 151,
#  'ninja': 152,
#  'closed': 153,
#  'did': 154,
#  'inexpensive': 155,
#  'least': 156,
#  'showed': 157,
#  'need': 158,
#  'fantastic': 159,
#  'saving': 160,
#  'over-hip': 161,
#  'nachos': 162,
#  'consistent': 163,
#  'seasoning': 164,
#  'stretch': 165,
#  'serivce': 166,
#  'total': 167,
#  'despite': 168,
#  'tots': 169,
#  'world': 170,
#  'hello': 171,
#  'surprise': 172,
#  'fo': 173,
#  'preparing': 174,
#  'meh': 175,
#  'tucson': 176,
#  'receives': 177,
#  'tolerance': 178,
#  'attack': 179,
#  'chewy': 180,
#  'bits': 181,
#  'across': 182,
#  'negligent': 183,
#  'meals': 184,
#  'quality': 185,
#  'via': 186,
#  'sliced': 187,
#  'toast': 188,
#  'none': 189,
#  'chow': 190,
#  'dedicated': 191,
#  'during': 192,
#  'bathrooms': 193,
#  'hits': 194,
#  'check': 195,
#  'job': 196,
#  'charming': 197,
#  'boyfriend': 198,
#  'disgusting': 199,
#  'wire': 200,
#  'soon': 201,
#  'worse': 202,
#  'thin': 203,
#  'melt': 204,
#  'sides': 205,
#  'chipolte': 206,
#  'water': 207,
#  'disgraceful': 208,
#  'particular': 209,
#  'disgrace': 210,
#  'may': 211,
#  'expanded': 212,
#  'turkey': 213,
#  'thirty': 214,
#  'yellow': 215,
#  'play': 216,
#  'mouthful': 217,
#  'paid': 218,
#  'send': 219,
#  'anytime': 220,
#  'real': 221,
#  'special': 222,
#  'mention': 223,
#  'refused': 224,
#  'meatballs': 225,
#  'tuna': 226,
#  'twice': 227,
#  'portions': 228,
#  'seasonal': 229,
#  'hot': 230,
#  'extraordinary': 231,
#  'thus': 232,
#  'quite': 233,
#  'service-check': 234,
#  'favor': 235,
#  'accordingly': 236,
#  'exquisite': 237,
#  'hunan': 238,
#  'mouths': 239,
#  'foods': 240,
#  'flat': 241,
#  'marrow': 242,
#  'regular': 243,
#  'actual': 244,
#  'selections': 245,
#  'clean': 246,
#  'worker': 247,
#  'japanese': 248,
#  'vegas': 249,
#  'employees': 250,
#  'claimed': 251,
#  'tap': 252,
#  'desired': 253,
#  'slices': 254,
#  'damn': 255,
#  'imaginative': 256,
#  'greens': 257,
#  'fact': 258,
#  'onion': 259,
#  'topic': 260,
#  'pulled': 261,
#  'beauty': 262,
#  'dog': 263,
#  'wasted': 264,
#  'fries': 265,
#  'after': 266,
#  'servers': 267,
#  'patron': 268,
#  'kitchen': 269,
#  'sushi': 270,
#  'main': 271,
#  'top': 272,
#  'plastic': 273,
#  'mushroom': 274,
#  'lastly': 275,
#  'options': 276,
#  'sign': 277,
#  'strangers': 278,
#  'everything': 279,
#  'truffle': 280,
#  'rock': 281,
#  'as': 282,
#  'hottest': 283,
#  'taco': 284,
#  'him': 285,
#  'summary': 286,
#  'apologize': 287,
#  'low': 288,
#  'songs': 289,
#  'yellowtail': 290,
#  'today': 291,
#  'pleasure': 292,
#  'stir': 293,
#  'take': 294,
#  'coconut': 295,
#  'cooked': 296,
#  'frenchman': 297,
#  'waaaaaayyyyyyyyyy': 298,
#  'classy/warm': 299,
#  'stuff': 300,
#  'appetizers': 301,
#  'fresh': 302,
#  'under': 303,
#  'surprised': 304,
#  'duo': 305,
#  'returned': 306,
#  'gluten': 307,
#  'multi-grain': 308,
#  '7': 309,
#  'friend': 310,
#  'opposed': 311,
#  'awful': 312,
#  'cooking': 313,
#  'occasional': 314,
#  'biscuit': 315,
#  'customer': 316,
#  'weird': 317,
#  'boring': 318,
#  'venturing': 319,
#  'north': 320,
#  'rings': 321,
#  'arriving': 322,
#  'perfectly': 323,
#  'firehouse': 324,
#  'fav': 325,
#  'hospitality': 326,
#  '*': 327,
#  'flavorless': 328,
#  'paper': 329,
#  'pissd': 330,
#  'cut': 331,
#  'bruschetta': 332,
#  'tasty': 333,
#  'sense': 334,
#  'bargain': 335,
#  'etc': 336,
#  'upgrading': 337,
#  'roast': 338,
#  'similar': 339,
#  'hopes': 340,
#  'reviewing..': 341,
#  'over': 342,
#  'sour': 343,
#  'colder': 344,
#  'girlfriend': 345,
#  'mandalay': 346,
#  'ramsey': 347,
#  'voted': 348,
#  'smashburger': 349,
#  'jeff': 350,
#  'cook': 351,
#  'hardest': 352,
#  'poisoning': 353,
#  'ever': 354,
#  'elk': 355,
#  'reason': 356,
#  ':': 357,
#  'seated': 358,
#  'offers': 359,
#  'menu': 360,
#  'anyways': 361,
#  'gets': 362,
#  'chipotle': 363,
#  'madison': 364,
#  'eaten': 365,
#  'neither': 366,
#  'smoothies': 367,
#  'joint': 368,
#  'awesome': 369,
#  'included': 370,
#  'court': 371,
#  'inspired': 372,
#  'ice': 373,
#  'greek': 374,
#  'flavored': 375,
#  'decent': 376,
#  'price': 377,
#  'witnessed': 378,
#  'passed': 379,
#  'screwed': 380,
#  'my': 381,
#  'realized': 382,
#  'killer': 383,
#  'either': 384,
#  'nobu': 385,
#  ')': 386,
#  'auju': 387,
#  'loves': 388,
#  'fry': 389,
#  'fat': 390,
#  'recommended': 391,
#  'airline': 392,
#  'by': 393,
#  'plus': 394,
#  'changing': 395,
#  'buying': 396,
#  'andddd': 397,
#  'give': 398,
#  'peanuts': 399,
#  'family': 400,
#  'officially': 401,
#  'done': 402,
#  'recent': 403,
#  'expectations': 404,
#  '6': 405,
#  'point': 406,
#  'said': 407,
#  'bird': 408,
#  'unsatisfying': 409,
#  'location': 410,
#  'things': 411,
#  'maria': 412,
#  'generous': 413,
#  'allergy': 414,
#  'extremely': 415,
#  'how': 416,
#  'once': 417,
#  'to-go': 418,
#  'liked': 419,
#  'certainly': 420,
#  'spaghetti': 421,
#  'whenever': 422,
#  'concept': 423,
#  'butter': 424,
#  'gyros': 425,
#  'wienerschnitzel': 426,
#  'fondue': 427,
#  'disbelief': 428,
#  'peach': 429,
#  'classic': 430,
#  'opinion': 431,
#  'perpared': 432,
#  'memory': 433,
#  'rushed': 434,
#  'huevos': 435,
#  'should': 436,
#  'chinese': 437,
#  'grossed': 438,
#  '2': 439,
#  'watched': 440,
#  'seafood': 441,
#  'downright': 442,
#  'used': 443,
#  'mango': 444,
#  'shrimp': 445,
#  'coupons': 446,
#  'chickens': 447,
#  'remember': 448,
#  'immediately': 449,
#  'thinly': 450,
#  'dealing': 451,
#  'atmosphere.1': 452,
#  'still': 453,
#  'driving': 454,
#  'accomodate': 455,
#  '.way': 456,
#  'week': 457,
#  'tried': 458,
#  'typical': 459,
#  'famous': 460,
#  'anyway': 461,
#  'proclaimed': 462,
#  'on': 463,
#  'such': 464,
#  'server': 465,
#  'largely': 466,
#  'fail': 467,
#  'poured': 468,
#  'freezing': 469,
#  'touch': 470,
#  'vanilla': 471,
#  'filling': 472,
#  '?': 473,
#  'carbs': 474,
#  'less': 475,
#  'down': 476,
#  'tell': 477,
#  'pop': 478,
#  'rotating': 479,
#  'burned': 480,
#  'baseball': 481,
#  'gratuity': 482,
#  'likes': 483,
#  'ironman': 484,
#  'yelpers': 485,
#  'about': 486,
#  'unless': 487,
#  'coziness': 488,
#  'tonight': 489,
#  'stars': 490,
#  'café': 491,
#  'spring': 492,
#  'part': 493,
#  'stayed': 494,
#  'thinking': 495,
#  'combination': 496,
#  'sit-down': 497,
#  'velvet': 498,
#  'patty': 499,
#  'appealing': 500,
#  'modern': 501,
#  'warm': 502,
#  'experience': 503,
#  'soundtrack': 504,
#  'thanks': 505,
#  'disgusted': 506,
#  'milkshake': 507,
#  'nude': 508,
#  'interesting': 509,
#  'number': 510,
#  'been-stepped-in-and-tracked-everywhere': 511,
#  'ryan': 512,
#  'ayce': 513,
#  'forth': 514,
#  'oysters': 515,
#  'red': 516,
#  'winner': 517,
#  'interior': 518,
#  'blah': 519,
#  'hardly': 520,
#  'say': 521,
#  'round': 522,
#  'market': 523,
#  'furthermore': 524,
#  'unwelcome': 525,
#  'chocolate': 526,
#  'pineapple': 527,
#  'military': 528,
#  'overhaul': 529,
#  'any': 530,
#  'last': 531,
#  'cold': 532,
#  'sitting': 533,
#  'checked': 534,
#  'hated': 535,
#  'prefer': 536,
#  'employee': 537,
#  'cake': 538,
#  'cover': 539,
#  'else': 540,
#  'greatest': 541,
#  'reminded': 542,
#  'somethat': 543,
#  'beateous': 544,
#  'taste': 545,
#  'put': 546,
#  'khao': 547,
#  'provides': 548,
#  '10': 549,
#  'mains': 550,
#  'lover': 551,
#  'difference': 552,
#  'fellow': 553,
#  'asking': 554,
#  'yukon': 555,
#  'slow': 556,
#  'review': 557,
#  'enjoy': 558,
#  'unwrapped': 559,
#  'waitress': 560,
#  'rib': 561,
#  'late': 562,
#  'living': 563,
#  'subway': 564,
#  'including': 565,
#  'in-house': 566,
#  'good': 567,
#  'few': 568,
#  'pile': 569,
#  'really': 570,
#  'short': 571,
#  'humiliated': 572,
#  'eew': 573,
#  'tepid': 574,
#  'nothing': 575,
#  'brother': 576,
#  'for': 577,
#  'basically': 578,
#  'forward': 579,
#  'return': 580,
#  'husband': 581,
#  'behind': 582,
#  'plain': 583,
#  'vibe': 584,
#  'informative': 585,
#  'sashimi': 586,
#  'soups': 587,
#  'valley': 588,
#  'limited': 589,
#  'event': 590,
#  'disappointing': 591,
#  'drink': 592,
#  'bloodiest': 593,
#  "'m": 594,
#  'disagree': 595,
#  'delight': 596,
#  'never': 597,
#  'dishes': 598,
#  'postinos': 599,
#  'bank': 600,
#  'croutons': 601,
#  'pho': 602,
#  'burger': 603,
#  'her': 604,
#  'crumby': 605,
#  'light': 606,
#  'several': 607,
#  '4': 608,
#  'beat': 609,
#  'quickly': 610,
#  'impressed': 611,
#  'otto': 612,
#  'over-whelm': 613,
#  'were': 614,
#  'somehow': 615,
#  '1/2': 616,
#  'almost': 617,
#  'helpful': 618,
#  'dime': 619,
#  'falafels': 620,
#  'literally': 621,
#  'bacon': 622,
#  'downtown': 623,
#  'does': 624,
#  'array': 625,
#  'profiterole': 626,
#  'touched': 627,
#  'me': 628,
#  'one': 629,
#  'third': 630,
#  'stale': 631,
#  'luck': 632,
#  'san': 633,
#  'trips': 634,
#  'elsewhere': 635,
#  'completely': 636,
#  'years': 637,
#  'cheesecurds': 638,
#  'movies': 639,
#  'car': 640,
#  'between': 641,
#  'juries': 642,
#  'approval': 643,
#  'gourmet': 644,
#  'worries': 645,
#  'name': 646,
#  'company': 647,
#  'saying': 648,
#  'tasted': 649,
#  'pastas': 650,
#  'wound': 651,
#  "'d": 652,
#  'go': 653,
#  'bathroom': 654,
#  'delicioso': 655,
#  'ribeye': 656,
#  'philadelphia': 657,
#  'left': 658,
#  'm': 659,
#  'right': 660,
#  'table': 661,
#  'pricing': 662,
#  'yay': 663,
#  'rudely': 664,
#  't.': 665,
#  'biscuits': 666,
#  'vegetarian': 667,
#  'sample': 668,
#  'raspberry': 669,
#  'high-quality': 670,
#  'putting': 671,
#  'handling': 672,
#  'cibo': 673,
#  'biggest': 674,
#  'sals': 675,
#  'burrittos': 676,
#  'soggy': 677,
#  'took': 678,
#  'burgers': 679,
#  'sauce': 680,
#  'delivery': 681,
#  'peanut': 682,
#  'larger': 683,
#  'piece': 684,
#  'hereas': 685,
#  'beans': 686,
#  'petty': 687,
#  'outdoor': 688,
#  'pros': 689,
#  '7.85': 690,
#  'seriously': 691,
#  'breaks': 692,
#  'meats': 693,
#  'tater': 694,
#  'subpar': 695,
#  'hooked': 696,
#  'asked': 697,
#  'las': 698,
#  'seems': 699,
#  'dirty': 700,
#  '-my': 701,
#  'del': 702,
#  'favorite': 703,
#  'fucking': 704,
#  'make': 705,
#  'welcome': 706,
#  'christmas': 707,
#  'above': 708,
#  'waited': 709,
#  'creamy': 710,
#  '.off': 711,
#  'crispy': 712,
#  'if': 713,
#  'wasting': 714,
#  'accident': 715,
#  'a': 716,
#  'relationship': 717,
#  'terrible': 718,
#  'kids': 719,
#  'conclusion': 720,
#  'relleno': 721,
#  'blown': 722,
#  'show': 723,
#  'thumbs': 724,
#  'events': 725,
#  'recommending': 726,
#  'francisco': 727,
#  'maintaining': 728,
#  'charge': 729,
#  'tiramisu': 730,
#  'pretty': 731,
#  'person': 732,
#  'seen': 733,
#  'instead': 734,
#  'underwhelming': 735,
#  'mediocre': 736,
#  'dark': 737,
#  'happy': 738,
#  'nutshell': 739,
#  'mac': 740,
#  'untoasted': 741,
#  'rare': 742,
#  'gringos': 743,
#  'bye': 744,
#  'ians': 745,
#  'contain': 746,
#  'guys': 747,
#  'rinse': 748,
#  'way': 749,
#  'professional': 750,
#  'space': 751,
#  'cod': 752,
#  'magic': 753,
#  'times': 754,
#  '(': 755,
#  'reminds': 756,
#  'grease': 757,
#  'wines': 758,
#  'so': 759,
#  "''": 760,
#  'genuinely': 761,
#  'playing': 762,
#  'imagine': 763,
#  'fine': 764,
#  'thai': 765,
#  'yourself': 766,
#  'con': 767,
#  'takeout': 768,
#  'works': 769,
#  'outta': 770,
#  'gone': 771,
#  'worst': 772,
#  'metro': 773,
#  'set': 774,
#  'middle': 775,
#  'golden-crispy': 776,
#  'garlic': 777,
#  'loudly': 778,
#  'past': 779,
#  'forty': 780,
#  'thoroughly': 781,
#  'original': 782,
#  'lighting': 783,
#  'outshining': 784,
#  'club': 785,
#  'haunt': 786,
#  'suggestions': 787,
#  'pictures': 788,
#  'orders': 789,
#  'ordering': 790,
#  'pepper..and': 791,
#  'use': 792,
#  'deliver': 793,
#  'flair': 794,
#  'bussell': 795,
#  'concern': 796,
#  '$': 797,
#  'rice': 798,
#  'blue': 799,
#  'fillet': 800,
#  'smaller': 801,
#  'piano': 802,
#  'gordon': 803,
#  'inviting': 804,
#  'mellow': 805,
#  'strike': 806,
#  'workers': 807,
#  'lived': 808,
#  'hours': 809,
#  'lunch': 810,
#  'spicy': 811,
#  'spot': 812,
#  'not': 813,
#  'gristle': 814,
#  'mesquite': 815,
#  'while': 816,
#  'gratitude': 817,
#  'unique': 818,
#  '1.5lb': 819,
#  'little': 820,
#  'ravoli': 821,
#  'pats': 822,
#  'app': 823,
#  'edible': 824,
#  'indoor': 825,
#  'ground': 826,
#  'ganoush': 827,
#  'brushfire': 828,
#  'insanely': 829,
#  'why': 830,
#  'pricey': 831,
#  'almonds': 832,
#  'vain': 833,
#  'hole': 834,
#  'ladies': 835,
#  'grab': 836,
#  'inconsiderate': 837,
#  'meal': 838,
#  '*heart*': 839,
#  'money': 840,
#  'jerk': 841,
#  'reasonable': 842,
#  'salty': 843,
#  'sexy': 844,
#  'truly': 845,
#  'carly': 846,
#  'fuzzy': 847,
#  'sun': 848,
#  'climbing': 849,
#  'however': 850,
#  'area/': 851,
#  'owned': 852,
#  'there': 853,
#  'proven': 854,
#  'bars': 855,
#  'funny': 856,
#  'latte': 857,
#  '``': 858,
#  'please': 859,
#  'alone': 860,
#  'something': 861,
#  'wait': 862,
#  'despicable': 863,
#  "'s": 864,
#  'crisp': 865,
#  'out': 866,
#  'iced': 867,
#  'rubber': 868,
#  'bigger': 869,
#  'focused': 870,
#  'mushrooms': 871,
#  'caterpillar': 872,
#  'here': 873,
#  'turn': 874,
#  'tables': 875,
#  'cart': 876,
#  'sucked': 877,
#  'ethic': 878,
#  'dusted': 879,
#  'donut': 880,
#  'spend': 881,
#  'decide': 882,
#  'poor': 883,
#  'waiting': 884,
#  'capers': 885,
#  'rated': 886,
#  'apparently': 887,
#  'anyone': 888,
#  'watered': 889,
#  'anymore': 890,
#  'businesses': 891,
#  'weekend': 892,
#  'boys': 893,
#  'ten': 894,
#  'food': 895,
#  'tastings': 896,
#  'watch': 897,
#  'avocado': 898,
#  'mexican': 899,
#  'wow': 900,
#  'dried': 901,
#  'sub': 902,
#  'parents': 903,
#  'rest': 904,
#  'char': 905,
#  'crowds': 906,
#  'steaks': 907,
#  'nut': 908,
#  'chai': 909,
#  'always': 910,
#  'bakery': 911,
#  'business': 912,
#  'goat': 913,
#  'dylan': 914,
#  'reheated': 915,
#  '...': 916,
#  'refrained': 917,
#  'come': 918,
#  'spends': 919,
#  'nigiri': 920,
#  'getting': 921,
#  'blow': 922,
#  'vinaigrette': 923,
#  'steak': 924,
#  'multiple': 925,
#  'fly': 926,
#  'sunday': 927,
#  'suck': 928,
#  'leave': 929,
#  'ignore': 930,
#  'handed': 931,
#  'arrived': 932,
#  'read': 933,
#  'buffet': 934,
#  'box': 935,
#  "'": 936,
#  'eve': 937,
#  'cakes': 938,
#  'deliciously': 939,
#  'have': 940,
#  'party': 941,
#  'verge': 942,
#  'afternoon': 943,
#  'probably': 944,
#  'item': 945,
#  'mid': 946,
#  'ala': 947,
#  'accountant': 948,
#  'unprofessional': 949,
#  'now': 950,
#  'honor': 951,
#  'and': 952,
#  'article': 953,
#  'familiar': 954,
#  'eggplant': 955,
#  '20': 956,
#  'mary': 957,
#  'tragedy': 958,
#  'dough': 959,
#  'ri': 960,
#  'palm': 961,
#  'again': 962,
#  'around': 963,
#  'see': 964,
#  'drenched': 965,
#  'shops': 966,
#  'rapidly': 967,
#  'grow': 968,
#  'just': 969,
#  'nan': 970,
#  'side': 971,
#  'mistake': 972,
#  'yet': 973,
#  'boba': 974,
#  'store': 975,
#  'serving': 976,
#  'single': 977,
#  'has': 978,
#  'trap': 979,
#  'bowl': 980,
#  'couple': 981,
#  'moods': 982,
#  'insults': 983,
#  'profound': 984,
#  'temp.i': 985,
#  'occasions': 986,
#  'hawaiian': 987,
#  'scene': 988,
#  'vodka': 989,
#  'fast': 990,
#  '2007': 991,
#  'looks': 992,
#  'mind': 993,
#  'second': 994,
#  'fare': 995,
#  'honest': 996,
#  'flower': 997,
#  'mozzarella': 998,
#  'ordered': 999,
#  ...}

# %%
index_word
# Out:
# {0: 'Wow',
#  1: '...',
#  2: 'Loved',
#  3: 'this',
#  4: 'place',
#  5: '.',
#  6: 'Crust',
#  7: 'is',
#  8: 'not',
#  9: 'good',
#  10: '.',
#  11: 'Not',
#  12: 'tasty',
#  13: 'and',
#  14: 'the',
#  15: 'texture',
#  16: 'was',
#  17: 'just',
#  18: 'nasty',
#  19: '.',
#  20: 'Stopped',
#  21: 'by',
#  22: 'during',
#  23: 'the',
#  24: 'late',
#  25: 'May',
#  26: 'bank',
#  27: 'holiday',
#  28: 'off',
#  29: 'Rick',
#  30: 'Steve',
#  31: 'recommendation',
#  32: 'and',
#  33: 'loved',
#  34: 'it',
#  35: '.',
#  36: 'The',
#  37: 'selection',
#  38: 'on',
#  39: 'the',
#  40: 'menu',
#  41: 'was',
#  42: 'great',
#  43: 'and',
#  44: 'so',
#  45: 'were',
#  46: 'the',
#  47: 'prices',
#  48: '.',
#  49: 'Now',
#  50: 'I',
#  51: 'am',
#  52: 'getting',
#  53: 'angry',
#  54: 'and',
#  55: 'I',
#  56: 'want',
#  57: 'my',
#  58: 'damn',
#  59: 'pho',
#  60: '.',
#  61: 'Honeslty',
#  62: 'it',
#  63: 'did',
#  64: "n't",
#  65: 'taste',
#  66: 'THAT',
#  67: 'fresh',
#  68: '.',
#  69: ')',
#  70: 'The',
#  71: 'potatoes',
#  72: 'were',
#  73: 'like',
#  74: 'rubber',
#  75: 'and',
#  76: 'you',
#  77: 'could',
#  78: 'tell',
#  79: 'they',
#  80: 'had',
#  81: 'been',
#  82: 'made',
#  83: 'up',
#  84: 'ahead',
#  85: 'of',
#  86: 'time',
#  87: 'being',
#  88: 'kept',
#  89: 'under',
#  90: 'a',
#  91: 'warmer',
#  92: '.',
#  93: 'The',
#  94: 'fries',
#  95: 'were',
#  96: 'great',
#  97: 'too',
#  98: '.',
#  99: 'A',
#  100: 'great',
#  101: 'touch',
#  102: '.',
#  103: 'Service',
#  104: 'was',
#  105: 'very',
#  106: 'prompt',
#  107: '.',
#  108: 'Would',
#  109: 'not',
#  110: 'go',
#  111: 'back',
#  112: '.',
#  113: 'The',
#  114: 'cashier',
#  115: 'had',
#  116: 'no',
#  117: 'care',
#  118: 'what',
#  119: 'so',
#  120: 'ever',
#  121: 'on',
#  122: 'what',
#  123: 'I',
#  124: 'had',
#  125: 'to',
#  126: 'say',
#  127: 'it',
#  128: 'still',
#  129: 'ended',
#  130: 'up',
#  131: 'being',
#  132: 'wayyy',
#  133: 'overpriced',
#  134: '.',
#  135: 'I',
#  136: 'tried',
#  137: 'the',
#  138: 'Cape',
#  139: 'Cod',
#  140: 'ravoli',
#  141: ',',
#  142: 'chicken',
#  143: ',',
#  144: 'with',
#  145: 'cranberry',
#  146: '...',
#  147: 'mmmm',
#  148: '!',
#  149: 'I',
#  150: 'was',
#  151: 'disgusted',
#  152: 'because',
#  153: 'I',
#  154: 'was',
#  155: 'pretty',
#  156: 'sure',
#  157: 'that',
#  158: 'was',
#  159: 'human',
#  160: 'hair',
#  161: '.',
#  162: 'I',
#  163: 'was',
#  164: 'shocked',
#  165: 'because',
#  166: 'no',
#  167: 'signs',
#  168: 'indicate',
#  169: 'cash',
#  170: 'only',
#  171: '.',
#  172: 'Highly',
#  173: 'recommended',
#  174: '.',
#  175: 'Waitress',
#  176: 'was',
#  177: 'a',
#  178: 'little',
#  179: 'slow',
#  180: 'in',
#  181: 'service',
#  182: '.',
#  183: 'This',
#  184: 'place',
#  185: 'is',
#  186: 'not',
#  187: 'worth',
#  188: 'your',
#  189: 'time',
#  190: ',',
#  191: 'let',
#  192: 'alone',
#  193: 'Vegas',
#  194: '.',
#  195: 'did',
#  196: 'not',
#  197: 'like',
#  198: 'at',
#  199: 'all',
#  200: '.',
#  201: 'The',
#  202: 'Burrittos',
#  203: 'Blah',
#  204: '!',
#  205: 'The',
#  206: 'food',
#  207: ',',
#  208: 'amazing',
#  209: '.',
#  210: 'Service',
#  211: 'is',
#  212: 'also',
#  213: 'cute',
#  214: '.',
#  215: 'I',
#  216: 'could',
#  217: 'care',
#  218: 'less',
#  219: '...',
#  220: 'The',
#  221: 'interior',
#  222: 'is',
#  223: 'just',
#  224: 'beautiful',
#  225: '.',
#  226: 'So',
#  227: 'they',
#  228: 'performed',
#  229: '.',
#  230: 'That',
#  231: "'s",
#  232: 'right',
#  233: '...',
#  234: '.the',
#  235: 'red',
#  236: 'velvet',
#  237: 'cake',
#  238: '...',
#  239: '..ohhh',
#  240: 'this',
#  241: 'stuff',
#  242: 'is',
#  243: 'so',
#  244: 'good',
#  245: '.',
#  246: '-',
#  247: 'They',
#  248: 'never',
#  249: 'brought',
#  250: 'a',
#  251: 'salad',
#  252: 'we',
#  253: 'asked',
#  254: 'for',
#  255: '.',
#  256: 'This',
#  257: 'hole',
#  258: 'in',
#  259: 'the',
#  260: 'wall',
#  261: 'has',
#  262: 'great',
#  263: 'Mexican',
#  264: 'street',
#  265: 'tacos',
#  266: ',',
#  267: 'and',
#  268: 'friendly',
#  269: 'staff',
#  270: '.',
#  271: 'Took',
#  272: 'an',
#  273: 'hour',
#  274: 'to',
#  275: 'get',
#  276: 'our',
#  277: 'food',
#  278: 'only',
#  279: '4',
#  280: 'tables',
#  281: 'in',
#  282: 'restaurant',
#  283: 'my',
#  284: 'food',
#  285: 'was',
#  286: 'Luke',
#  287: 'warm',
#  288: ',',
#  289: 'Our',
#  290: 'sever',
#  291: 'was',
#  292: 'running',
#  293: 'around',
#  294: 'like',
#  295: 'he',
#  296: 'was',
#  297: 'totally',
#  298: 'overwhelmed',
#  299: '.',
#  300: 'The',
#  301: 'worst',
#  302: 'was',
#  303: 'the',
#  304: 'salmon',
#  305: 'sashimi',
#  306: '.',
#  307: 'Also',
#  308: 'there',
#  309: 'are',
#  310: 'combos',
#  311: 'like',
#  312: 'a',
#  313: 'burger',
#  314: ',',
#  315: 'fries',
#  316: ',',
#  317: 'and',
#  318: 'beer',
#  319: 'for',
#  320: '23',
#  321: 'which',
#  322: 'is',
#  323: 'a',
#  324: 'decent',
#  325: 'deal',
#  326: '.',
#  327: 'This',
#  328: 'was',
#  329: 'like',
#  330: 'the',
#  331: 'final',
#  332: 'blow',
#  333: '!',
#  334: 'I',
#  335: 'found',
#  336: 'this',
#  337: 'place',
#  338: 'by',
#  339: 'accident',
#  340: 'and',
#  341: 'I',
#  342: 'could',
#  343: 'not',
#  344: 'be',
#  345: 'happier',
#  346: '.',
#  347: 'seems',
#  348: 'like',
#  349: 'a',
#  350: 'good',
#  351: 'quick',
#  352: 'place',
#  353: 'to',
#  354: 'grab',
#  355: 'a',
#  356: 'bite',
#  357: 'of',
#  358: 'some',
#  359: 'familiar',
#  360: 'pub',
#  361: 'food',
#  362: ',',
#  363: 'but',
#  364: 'do',
#  365: 'yourself',
#  366: 'a',
#  367: 'favor',
#  368: 'and',
#  369: 'look',
#  370: 'elsewhere',
#  371: '.',
#  372: 'Overall',
#  373: ',',
#  374: 'I',
#  375: 'like',
#  376: 'this',
#  377: 'place',
#  378: 'a',
#  379: 'lot',
#  380: '.',
#  381: 'The',
#  382: 'only',
#  383: 'redeeming',
#  384: 'quality',
#  385: 'of',
#  386: 'the',
#  387: 'restaurant',
#  388: 'was',
#  389: 'that',
#  390: 'it',
#  391: 'was',
#  392: 'very',
#  393: 'inexpensive',
#  394: '.',
#  395: 'Ample',
#  396: 'portions',
#  397: 'and',
#  398: 'good',
#  399: 'prices',
#  400: '.',
#  401: 'Poor',
#  402: 'service',
#  403: ',',
#  404: 'the',
#  405: 'waiter',
#  406: 'made',
#  407: 'me',
#  408: 'feel',
#  409: 'like',
#  410: 'I',
#  411: 'was',
#  412: 'stupid',
#  413: 'every',
#  414: 'time',
#  415: 'he',
#  416: 'came',
#  417: 'to',
#  418: 'the',
#  419: 'table',
#  420: '.',
#  421: 'My',
#  422: 'first',
#  423: 'visit',
#  424: 'to',
#  425: 'Hiro',
#  426: 'was',
#  427: 'a',
#  428: 'delight',
#  429: '!',
#  430: 'Service',
#  431: 'sucks',
#  432: '.',
#  433: 'The',
#  434: 'shrimp',
#  435: 'tender',
#  436: 'and',
#  437: 'moist',
#  438: '.',
#  439: 'There',
#  440: 'is',
#  441: 'not',
#  442: 'a',
#  443: 'deal',
#  444: 'good',
#  445: 'enough',
#  446: 'that',
#  447: 'would',
#  448: 'drag',
#  449: 'me',
#  450: 'into',
#  451: 'that',
#  452: 'establishment',
#  453: 'again',
#  454: '.',
#  455: 'Hard',
#  456: 'to',
#  457: 'judge',
#  458: 'whether',
#  459: 'these',
#  460: 'sides',
#  461: 'were',
#  462: 'good',
#  463: 'because',
#  464: 'we',
#  465: 'were',
#  466: 'grossed',
#  467: 'out',
#  468: 'by',
#  469: 'the',
#  470: 'melted',
#  471: 'styrofoam',
#  472: 'and',
#  473: 'did',
#  474: "n't",
#  475: 'want',
#  476: 'to',
#  477: 'eat',
#  478: 'it',
#  479: 'for',
#  480: 'fear',
#  481: 'of',
#  482: 'getting',
#  483: 'sick',
#  484: '.',
#  485: 'On',
#  486: 'a',
#  487: 'positive',
#  488: 'note',
#  489: ',',
#  490: 'our',
#  491: 'server',
#  492: 'was',
#  493: 'very',
#  494: 'attentive',
#  495: 'and',
#  496: 'provided',
#  497: 'great',
#  498: 'service',
#  499: '.',
#  500: 'Frozen',
#  501: 'pucks',
#  502: 'of',
#  503: 'disgust',
#  504: ',',
#  505: 'with',
#  506: 'some',
#  507: 'of',
#  508: 'the',
#  509: 'worst',
#  510: 'people',
#  511: 'behind',
#  512: 'the',
#  513: 'register',
#  514: '.',
#  515: 'The',
#  516: 'only',
#  517: 'thing',
#  518: 'I',
#  519: 'did',
#  520: 'like',
#  521: 'was',
#  522: 'the',
#  523: 'prime',
#  524: 'rib',
#  525: 'and',
#  526: 'dessert',
#  527: 'section',
#  528: '.',
#  529: 'It',
#  530: "'s",
#  531: 'too',
#  532: 'bad',
#  533: 'the',
#  534: 'food',
#  535: 'is',
#  536: 'so',
#  537: 'damn',
#  538: 'generic',
#  539: '.',
#  540: 'The',
#  541: 'burger',
#  542: 'is',
#  543: 'good',
#  544: 'beef',
#  545: ',',
#  546: 'cooked',
#  547: 'just',
#  548: 'right',
#  549: '.',
#  550: 'If',
#  551: 'you',
#  552: 'want',
#  553: 'a',
#  554: 'sandwich',
#  555: 'just',
#  556: 'go',
#  557: 'to',
#  558: 'any',
#  559: 'Firehouse',
#  560: '!',
#  561: '!',
#  562: '!',
#  563: '!',
#  564: '!',
#  565: 'My',
#  566: 'side',
#  567: 'Greek',
#  568: 'salad',
#  569: 'with',
#  570: 'the',
#  571: 'Greek',
#  572: 'dressing',
#  573: 'was',
#  574: 'so',
#  575: 'tasty',
#  576: ',',
#  577: 'and',
#  578: 'the',
#  579: 'pita',
#  580: 'and',
#  581: 'hummus',
#  582: 'was',
#  583: 'very',
#  584: 'refreshing',
#  585: '.',
#  586: 'We',
#  587: 'ordered',
#  588: 'the',
#  589: 'duck',
#  590: 'rare',
#  591: 'and',
#  592: 'it',
#  593: 'was',
#  594: 'pink',
#  595: 'and',
#  596: 'tender',
#  597: 'on',
#  598: 'the',
#  599: 'inside',
#  600: 'with',
#  601: 'a',
#  602: 'nice',
#  603: 'char',
#  604: 'on',
#  605: 'the',
#  606: 'outside',
#  607: '.',
#  608: 'He',
#  609: 'came',
#  610: 'running',
#  611: 'after',
#  612: 'us',
#  613: 'when',
#  614: 'he',
#  615: 'realized',
#  616: 'my',
#  617: 'husband',
#  618: 'had',
#  619: 'left',
#  620: 'his',
#  621: 'sunglasses',
#  622: 'on',
#  623: 'the',
#  624: 'table',
#  625: '.',
#  626: 'Their',
#  627: 'chow',
#  628: 'mein',
#  629: 'is',
#  630: 'so',
#  631: 'good',
#  632: '!',
#  633: 'They',
#  634: 'have',
#  635: 'horrible',
#  636: 'attitudes',
#  637: 'towards',
#  638: 'customers',
#  639: ',',
#  640: 'and',
#  641: 'talk',
#  642: 'down',
#  643: 'to',
#  644: 'each',
#  645: 'one',
#  646: 'when',
#  647: 'customers',
#  648: 'do',
#  649: "n't",
#  650: 'enjoy',
#  651: 'their',
#  652: 'food',
#  653: '.',
#  654: 'The',
#  655: 'portion',
#  656: 'was',
#  657: 'huge',
#  658: '!',
#  659: 'Loved',
#  660: 'it',
#  661: '...',
#  662: 'friendly',
#  663: 'servers',
#  664: ',',
#  665: 'great',
#  666: 'food',
#  667: ',',
#  668: 'wonderful',
#  669: 'and',
#  670: 'imaginative',
#  671: 'menu',
#  672: '.',
#  673: 'The',
#  674: 'Heart',
#  675: 'Attack',
#  676: 'Grill',
#  677: 'in',
#  678: 'downtown',
#  679: 'Vegas',
#  680: 'is',
#  681: 'an',
#  682: 'absolutely',
#  683: 'flat-lined',
#  684: 'excuse',
#  685: 'for',
#  686: 'a',
#  687: 'restaurant',
#  688: '.',
#  689: 'Not',
#  690: 'much',
#  691: 'seafood',
#  692: 'and',
#  693: 'like',
#  694: '5',
#  695: 'strings',
#  696: 'of',
#  697: 'pasta',
#  698: 'at',
#  699: 'the',
#  700: 'bottom',
#  701: '.',
#  702: 'The',
#  703: 'salad',
#  704: 'had',
#  705: 'just',
#  706: 'the',
#  707: 'right',
#  708: 'amount',
#  709: 'of',
#  710: 'sauce',
#  711: 'to',
#  712: 'not',
#  713: 'over',
#  714: 'power',
#  715: 'the',
#  716: 'scallop',
#  717: ',',
#  718: 'which',
#  719: 'was',
#  720: 'perfectly',
#  721: 'cooked',
#  722: '.',
#  723: 'The',
#  724: 'ripped',
#  725: 'banana',
#  726: 'was',
#  727: 'not',
#  728: 'only',
#  729: 'ripped',
#  730: ',',
#  731: 'but',
#  732: 'petrified',
#  733: 'and',
#  734: 'tasteless',
#  735: '.',
#  736: 'At',
#  737: 'least',
#  738: 'think',
#  739: 'to',
#  740: 'refill',
#  741: 'my',
#  742: 'water',
#  743: 'before',
#  744: 'I',
#  745: 'struggle',
#  746: 'to',
#  747: 'wave',
#  748: 'you',
#  749: 'over',
#  750: 'for',
#  751: '10',
#  752: 'minutes',
#  753: '.',
#  754: 'This',
#  755: 'place',
#  756: 'receives',
#  757: 'stars',
#  758: 'for',
#  759: 'their',
#  760: 'APPETIZERS',
#  761: '!',
#  762: '!',
#  763: '!',
#  764: 'The',
#  765: 'cocktails',
#  766: 'are',
#  767: 'all',
#  768: 'handmade',
#  769: 'and',
#  770: 'delicious',
#  771: '.',
#  772: 'We',
#  773: "'d",
#  774: 'definitely',
#  775: 'go',
#  776: 'back',
#  777: 'here',
#  778: 'again',
#  779: '.',
#  780: 'We',
#  781: 'are',
#  782: 'so',
#  783: 'glad',
#  784: 'we',
#  785: 'found',
#  786: 'this',
#  787: 'place',
#  788: '.',
#  789: 'Great',
#  790: 'food',
#  791: 'and',
#  792: 'service',
#  793: ',',
#  794: 'huge',
#  795: 'portions',
#  796: 'and',
#  797: 'they',
#  798: 'give',
#  799: 'a',
#  800: 'military',
#  801: 'discount',
#  802: '.',
#  803: 'Always',
#  804: 'a',
#  805: 'great',
#  806: 'time',
#  807: 'at',
#  808: 'Dos',
#  809: 'Gringos',
#  810: '!',
#  811: 'Update',
#  812: '...',
#  813: '..went',
#  814: 'back',
#  815: 'for',
#  816: 'a',
#  817: 'second',
#  818: 'time',
#  819: 'and',
#  820: 'it',
#  821: 'was',
#  822: 'still',
#  823: 'just',
#  824: 'as',
#  825: 'amazing',
#  826: 'We',
#  827: 'got',
#  828: 'the',
#  829: 'food',
#  830: 'and',
#  831: 'apparently',
#  832: 'they',
#  833: 'have',
#  834: 'never',
#  835: 'heard',
#  836: 'of',
#  837: 'salt',
#  838: 'and',
#  839: 'the',
#  840: 'batter',
#  841: 'on',
#  842: 'the',
#  843: 'fish',
#  844: 'was',
#  845: 'chewy',
#  846: '.',
#  847: 'A',
#  848: 'great',
#  849: 'way',
#  850: 'to',
#  851: 'finish',
#  852: 'a',
#  853: 'great',
#  854: '.',
#  855: 'The',
#  856: 'deal',
#  857: 'included',
#  858: '5',
#  859: 'tastings',
#  860: 'and',
#  861: '2',
#  862: 'drinks',
#  863: ',',
#  864: 'and',
#  865: 'Jeff',
#  866: 'went',
#  867: 'above',
#  868: 'and',
#  869: 'beyond',
#  870: 'what',
#  871: 'we',
#  872: 'expected',
#  873: '.',
#  874: '-',
#  875: 'Really',
#  876: ',',
#  877: 'really',
#  878: 'good',
#  879: 'rice',
#  880: ',',
#  881: 'all',
#  882: 'the',
#  883: 'time',
#  884: '.',
#  885: 'The',
#  886: 'service',
#  887: 'was',
#  888: 'meh',
#  889: '.',
#  890: 'It',
#  891: 'took',
#  892: 'over',
#  893: '30',
#  894: 'min',
#  895: 'to',
#  896: 'get',
#  897: 'their',
#  898: 'milkshake',
#  899: ',',
#  900: 'which',
#  901: 'was',
#  902: 'nothing',
#  903: 'more',
#  904: 'than',
#  905: 'chocolate',
#  906: 'milk',
#  907: '.',
#  908: 'I',
#  909: 'guess',
#  910: 'I',
#  911: 'should',
#  912: 'have',
#  913: 'known',
#  914: 'that',
#  915: 'this',
#  916: 'place',
#  917: 'would',
#  918: 'suck',
#  919: ',',
#  920: 'because',
#  921: 'it',
#  922: 'is',
#  923: 'inside',
#  924: 'of',
#  925: 'the',
#  926: 'Excalibur',
#  927: ',',
#  928: 'but',
#  929: 'I',
#  930: 'did',
#  931: "n't",
#  932: 'use',
#  933: 'my',
#  934: 'common',
#  935: 'sense',
#  936: '.',
#  937: 'The',
#  938: 'scallop',
#  939: 'dish',
#  940: 'is',
#  941: 'quite',
#  942: 'appalling',
#  943: 'for',
#  944: 'value',
#  945: 'as',
#  946: 'well',
#  947: '.',
#  948: '2',
#  949: 'times',
#  950: '-',
#  951: 'Very',
#  952: 'Bad',
#  953: 'Customer',
#  954: 'Service',
#  955: '!',
#  956: 'The',
#  957: 'sweet',
#  958: 'potato',
#  959: 'fries',
#  960: 'were',
#  961: 'very',
#  962: 'good',
#  963: 'and',
#  964: 'seasoned',
#  965: 'well',
#  966: '.',
#  967: 'Today',
#  968: 'is',
#  969: 'the',
#  970: 'second',
#  971: 'time',
#  972: 'I',
#  973: "'ve",
#  974: 'been',
#  975: 'to',
#  976: 'their',
#  977: 'lunch',
#  978: 'buffet',
#  979: 'and',
#  980: 'it',
#  981: 'was',
#  982: 'pretty',
#  983: 'good',
#  984: '.',
#  985: 'There',
#  986: 'is',
#  987: 'so',
#  988: 'much',
#  989: 'good',
#  990: 'food',
#  991: 'in',
#  992: 'Vegas',
#  993: 'that',
#  994: 'I',
#  995: 'feel',
#  996: 'cheated',
#  997: 'for',
#  998: 'wasting',
#  999: 'an',
#  ...}

# %% [markdown]
# ## 轉換句子為bag of words型式

# %%
def _get_bag_of_words_vector(sentence, word_index_dic, whole_words):
    sentence = sentence
    vector= np.zeros(len(whole_words))
    for word in nltk.word_tokenize(sentence):
        if word in whole_words:
            vector[word_index[word]] += 1
    return vector

# %%
_get_bag_of_words_vector('Wow... Loved this place.'.lower(), word_index, whole_words)
# Out:
# array([0., 0., 0., ..., 0., 0., 0.])
